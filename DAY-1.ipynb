# %% [markdown]
# <a href="https://colab.research.google.com/github/inoorulameen2005-crypto/Data-Analytics-using-python-project/blob/main/DAY-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DAY-1**

# %% [markdown]
# **TRY AND EXCEPT NUMBER**

# %%
try:
  num=int(input("enter number: "))
  print(num)
except:
  print("invalid input")
# Out:
# enter number: 123
# 123
